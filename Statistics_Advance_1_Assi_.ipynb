# %%
"""1. Explain the properties of the F-distribution. ?

#Ans . Here are some properties of the F-distribution:

#* Asymmetry: The F-distribution is skewed to the right and is not symmetrical.
#* Shape: The exact shape of the F-distribution depends on the degrees of freedom for the numerator and denominator.
#* Parameters: The F-distribution is defined by two parameters: the degrees of freedom of the numerator (
#* Range: The F-statistic is greater than or equal to zero.
#* Approximation: As the degrees of freedom for the numerator and denominator increase, the F-distribution approaches the normal distribution.
#* Uses: The F-distribution is used to compare variances and in two-way Analysis of Variance. It is also used in hypothesis testing.
#* Probability: The F-distribution provides a way to calculate the probability associated with the observed variance ratio."""

# %%
"""Que 2.In which types of statistical tests is the F-distribution used, and why is it appropriate for these tests?

Ans. The F-distribution is used in hypothesis testing, particularly in the analysis of variance (ANOVA) and the F-test:

F-test
Used to determine if two samples come from populations with the same variance. The F-test uses the F-statistic, which is the ratio of two sample variances.

ANOVA
Used to determine if three or more samples come from populations with the same mean. ANOVA uses the F-distribution to compare the ratio of two mean squares (variances) to determine if the differences between sample means are statistically significant.

The F-distribution is appropriate for these tests because it's generated by drawing two samples from the same normal population. """

"""

# %%
"""3. What are the key assumptions required for conducting an F-test to compare the variances of two populations


Ans . The key assumptions for conducting an F-test to compare the variances of two populations are:
*Normality: The data within each group follows a normal distribution

*Independence: The observations within each group are independent of each other

*Random sampling: The samples are randomly sampled from their respective populations

*The F-test is very sensitive to departure from the normal assumption, so it's important to check whether the normal assumption holds before using the F-test.
*If there is doubt about normality, it's better not to use the F-test.

When calculating the F-statistic, the larger variance is used as the numerator, and the smaller variance is used in the denominator. """

# %%
""" 4. What is the purpose of ANOVA, and how does it differ from a t-test?

Ans . The purpose of ANOVA (analysis of variance) is to compare the means of three or more groups, while the purpose of a t-test is to compare the means of two
groups:

*Purpose: ANOVA compares the means of three or more groups, while a t-test compares the means of two groups.

*Statistical significance: Both tests determine statistical significance in different ways.

*Sample size: A t-test compares two sample sizes (n) both below 30, while ANOVA equates three or more such groups.

*Error control: ANOVA controls for errors so that the Type I error remains at 5%.

Both tests are often used by students to evaluate data for research. They both look at the difference in means and the spread of distributions across groups, and
they are performed when the samples are independent of each other, have approximately normal distributions, and the sample number is high. """b

# %%
""" Que.5 Explain when and why you would use a one-way ANOVA instead of multiple t-tests when comparing more than two groups. ?

Ans . A one-way ANOVA is used instead of multiple t-tests when comparing more than two groups to avoid increasing the chance of making a Type I error:

Type I error
Each time a t-test is performed, there is a chance of making a Type I error, which is usually around 5%. The chance of making a mistake increases when multiple
t-tests are performed on the same data. For example, running two t-tests increases the chance of making a mistake to 10%.

ANOVA controls for errors
A one-way ANOVA controls for these errors so that the Type I error remains at 5%. This allows you to be more confident that any statistically significant result
 you find is not just running lots of tests.

One-way ANOVA can compare means across multiple groups
A one-way ANOVA can compare the means across three or more groups, while an independent samples t-test can only compare the means for two groups.

A one-way ANOVA is used when you have collected data about one categorical independent variable and one quantitative dependent variable. The independent variable
 should have at least three levels. """

# %%
""" Que 6 Explain how variance is partitioned in ANOVA into between-group variance and within-group variance. How does this partitioning contribute to the calculation of the
F-statistic?

In Analysis of Variance (ANOVA), variance is partitioned into between-group variance and within-group variance to assess if the differences in group means are
statistically significant. The F-statistic is calculated by dividing the mean square for between groups by the mean square within groups. The F-statistic is
used to determine if the null hypothesis is true, which states that all population means are the same.

Here's how variance is partitioned in ANOVA:
* Between-group variance: Measures how different the group means are from each other.
* Within-group variance: Reflects the variability within each group.

The F-statistic is a ratio of the two variances:
* Numerator: The variation between sample means
* Denominator: The variation within the samples

If the null hypothesis is true, the F-statistic will be close to 1. If the group assignment has an effect on the measurements, the F-statistic will be greater
than 1.

# %%
"""Que 7.Compare the classical (frequentist) approach to ANOVA with the Bayesian approach. What are the key differences in terms of how they handle uncertainty, parameter estimation,
and hypothesis testing?

Ans . The main difference between the frequentist and Bayesian approaches to statistics is how they handle uncertainty. Here are some ways the two approaches
compare:
*Uncertainty

Frequentist statistics relies on objective probabilities and long-term frequencies, while Bayesian statistics embraces subjective probabilities and the idea
that probabilities change based on new information.

*Parameter estimation
Frequentists use point estimates of unknown parameters to predict new data points, while Bayesians use a full posterior distribution over possible parameter
 values.

*Hypothesis testing
Frequentist statistics emphasizes hypothesis testing and confidence intervals.

*Data
Frequentists focus on observed data, while Bayesians consider previous assumptions.

*Data amount
Bayesians can proceed with as little as one datapoint, while frequentists spurn small datasets.

The choice between the two approaches depends on the nature of the problem, the availability of prior information, and the researcher's philosophical stance."""

# %%
# prompt: 8. Question: You have two sets of data representing the incomes of two different professions1
# V Profession A: [48, 52, 55, 60, 62'
# V Profession B: [45, 50, 55, 52, 47] Perform an F-test to determine if the variances of the two professions'
# incomes are equal. What are your conclusions based on the F-test?
# Task: Use Python to calculate the F-statistic and p-value for the given data.
# Objective: Gain experience in performing F-tests and interpreting the results in terms of variance comparison.

import numpy as np
from scipy.stats import f

# Income data for Profession A and Profession B
profession_a = np.array([48, 52, 55, 60, 62])
profession_b = np.array([45, 50, 55, 52, 47])

# Calculate the variances of the two professions' incomes
variance_a = np.var(profession_a, ddof=1)  # ddof=1 for sample variance
variance_b = np.var(profession_b, ddof=1)

# Calculate the F-statistic
f_statistic = variance_a / variance_b

# Calculate the degrees of freedom
df_a = len(profession_a) - 1
df_b = len(profession_b) - 1

# Calculate the p-value
p_value = f.sf(f_statistic, df_a, df_b)  # Survival function (1 - CDF)

print(f"F-statistic: {f_statistic:.2f}")
print(f"P-value: {p_value:.3f}")

# Interpret the results
alpha = 0.05  # Significance level

if p_value < alpha:
  print("The variances are significantly different.")
else:
  print("The variances are not significantly different.")
# Out:
# F-statistic: 2.09
# P-value: 0.247
# The variances are not significantly different.

# %%
#9. Question: Conduct a one-way ANOVA to test whether there are any statistically significant differences in
# average heights between three different regions with the following data1
# V Region A: [160, 162, 165, 158, 164'
# V Region B: [172, 175, 170, 168, 174'
# V Region C: [180, 182, 179, 185, 183'
# V Task: Write Python code to perform the one-way ANOVA and interpret the results
# V Objective: Learn how to perform one-way ANOVA using Python and interpret F-statistic and p-value.

import numpy as np
from scipy import stats

# Data for each region
region_a = np.array([160, 162, 165, 158, 164])
region_b = np.array([172, 175, 170, 168, 174])
region_c = np.array([180, 182, 179, 185, 183])

# Perform one-way ANOVA
f_statistic, p_value = stats.f_oneway(region_a, region_b, region_c)

# Print the results
print("F-statistic:", f_statistic)
print("P-value:", p_value)

# Interpret the results
alpha = 0.05  # Significance level
if p_value < alpha:
    print("There is a statistically significant difference in average heights between the regions.")
else:
    print("There is no statistically significant difference in average heights between the regions.")
# Out:
# F-statistic: 67.87330316742101
# P-value: 2.870664187937026e-07
# There is a statistically significant difference in average heights between the regions.
